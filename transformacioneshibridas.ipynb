# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayte-Tixi/Vision-Artificial/blob/main/transformacioneshibridas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar bibliotecas si es necesario
# !pip install opencv-python-headless matplotlib

# %%
# Montar Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar bibliotecas
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive

# %%
mejorando imagen 8  con transformacion lineal  conjuntamente con ecualizacion histograma para tener mejor resultado

# %%
image_path_1 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/1.png'
# Leer imagen en formato RGB y escala de grises
image_rgb_1 = cv2.imread(image_path_1)
image_rgb_1 = cv2.cvtColor(image_rgb_1, cv2.COLOR_BGR2RGB)
image_gray_1 = cv2.cvtColor(image_rgb_1, cv2.COLOR_RGB2GRAY)

# Similar configuración para el resto de imágenes
image_path_2 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/2.png'
image_rgb_2 = cv2.imread(image_path_2)
image_rgb_2 = cv2.cvtColor(image_rgb_2, cv2.COLOR_BGR2RGB)
image_gray_2 = cv2.cvtColor(image_rgb_2, cv2.COLOR_RGB2GRAY)

image_path_3 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/3.png'
image_rgb_3 = cv2.imread(image_path_3)
image_rgb_3 = cv2.cvtColor(image_rgb_3, cv2.COLOR_BGR2RGB)
image_gray_3 = cv2.cvtColor(image_rgb_3, cv2.COLOR_RGB2GRAY)

image_path_4 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/4.png'
image_rgb_4 = cv2.imread(image_path_4)
image_rgb_4 = cv2.cvtColor(image_rgb_4, cv2.COLOR_BGR2RGB)
image_gray_4 = cv2.cvtColor(image_rgb_4, cv2.COLOR_RGB2GRAY)

image_path_5 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/5.png'
image_rgb_5 = cv2.imread(image_path_5)
image_rgb_5 = cv2.cvtColor(image_rgb_5, cv2.COLOR_BGR2RGB)
image_gray_5 = cv2.cvtColor(image_rgb_5, cv2.COLOR_RGB2GRAY)

image_path_6 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/6.png'
image_rgb_6 = cv2.imread(image_path_6)
image_rgb_6 = cv2.cvtColor(image_rgb_6, cv2.COLOR_BGR2RGB)
image_gray_6 = cv2.cvtColor(image_rgb_6, cv2.COLOR_RGB2GRAY)

image_path_7 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/7.png'
image_rgb_7 = cv2.imread(image_path_7)
image_rgb_7 = cv2.cvtColor(image_rgb_7, cv2.COLOR_BGR2RGB)
image_gray_7 = cv2.cvtColor(image_rgb_7, cv2.COLOR_RGB2GRAY)

image_path_8 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/8.png'
image_rgb_8 = cv2.imread(image_path_8)
image_rgb_8 = cv2.cvtColor(image_rgb_8, cv2.COLOR_BGR2RGB)
image_gray_8 = cv2.cvtColor(image_rgb_8, cv2.COLOR_RGB2GRAY)

image_path_9 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/9.png'
image_rgb_9 = cv2.imread(image_path_9)
image_rgb_9 = cv2.cvtColor(image_rgb_9, cv2.COLOR_BGR2RGB)
image_gray_9 = cv2.cvtColor(image_rgb_9, cv2.COLOR_RGB2GRAY)

image_path_10 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/10.png'
image_rgb_10 = cv2.imread(image_path_10)
image_rgb_10 = cv2.cvtColor(image_rgb_10, cv2.COLOR_BGR2RGB)
image_gray_10 = cv2.cvtColor(image_rgb_10, cv2.COLOR_RGB2GRAY)

image_path_11 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/11.png'
image_rgb_11 = cv2.imread(image_path_11)
image_rgb_11 = cv2.cvtColor(image_rgb_11, cv2.COLOR_BGR2RGB)
image_gray_11 = cv2.cvtColor(image_rgb_11, cv2.COLOR_RGB2GRAY)

image_path_12 = '/content/drive/MyDrive/UNIR-Inteligencia Artificial/Cuatrimestre1/Vision Artificial/laboratorio/imagenes/12.png'
image_rgb_12 = cv2.imread(image_path_12)
image_rgb_12 = cv2.cvtColor(image_rgb_12, cv2.COLOR_BGR2RGB)
image_gray_12 = cv2.cvtColor(image_rgb_12, cv2.COLOR_RGB2GRAY)

# Mostrar la imagen 1 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_1)
plt.title('Imagen 1 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_1, cmap='gray')
plt.title('IMAGEN 1 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()

# Mostrar la imagen 2 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_2)
plt.title('Imagen 2 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_2, cmap='gray')
plt.title('IMAGEN 2 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()

# Mostrar la imagen 3 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_3)
plt.title('Imagen 3 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_3, cmap='gray')
plt.title('IMAGEN 3 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()



# Mostrar la imagen 6 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_6)
plt.title('Imagen 6 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_6, cmap='gray')
plt.title('IMAGEN 6 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()

# Mostrar la imagen 7 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_7)
plt.title('Imagen 7 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_7, cmap='gray')
plt.title('IMAGEN 7 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()

# Mostrar la imagen 8 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_8)
plt.title('Imagen 8 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_8, cmap='gray')
plt.title('IMAGEN 8 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()

# Mostrar la imagen 9 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_9)
plt.title('Imagen 9 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_9, cmap='gray')
plt.title('IMAGEN 9 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()



# Mostrar la imagen 11 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_11)
plt.title('Imagen 11 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_11, cmap='gray')
plt.title('IMAGEN 11 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()


# Mostrar la imagen 4 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_4)
plt.title('Imagen 4 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_4, cmap='gray')
plt.title('IMAGEN 4 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()

# Mostrar la imagen 5 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_5)
plt.title('Imagen 5 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_5, cmap='gray')
plt.title('IMAGEN 5 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()

# Mostrar la imagen 10 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_10)
plt.title('Imagen 10 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_10, cmap='gray')
plt.title('IMAGEN 10 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()


# Mostrar la imagen 12 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb_12)
plt.title('Imagen 12 RGB')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_gray_12, cmap='gray')
plt.title('IMAGEN 12 ORIGINAL ESCALA DE GRISES')
plt.axis('off')
plt.show()
